# %%
# Import dependencies
import matplotlib.pyplot as plt
import pandas as pd
from pprint import pprint
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the needed api key
from config import weather_api_key

# We need to get our cities from somewhere
from citipy import citipy

# Defining the output filepath
output_data = "output_data/cities.csv"

# Define lats and longs
latRange = (-90, 90)
lonRange = (-180, 180)

# %%
# Create empty lists to fill
latLng = []
cities = []

# Get random lats and longs
lat = np.random.uniform(low=-90.000, high=90.000, size=1500)
lng = np.random.uniform(low=-180.000, high=180.000, size=1500)
# Zip them together in the latLng list
latLng = zip(lat, lng)

# Match cities with the lats and longs
for x in latLng:
    city = citipy.nearest_city(x[0],x[1]).city_name

    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 585

# %%
print(cities)
# Out:
# ['alotau', 'port elizabeth', 'nizhneyansk', 'palana', 'punta arenas', 'aklavik', 'glace bay', 'ushtobe', 'tuktoyaktuk', 'rikitea', 'malanville', 'bredasdorp', 'pacific grove', 'magadan', 'bluff', 'ushuaia', 'broken hill', 'charters towers', 'ribeira grande', 'dikson', 'znamenskoye', 'half moon bay', 'mataura', 'san quintin', 'yellowknife', 'busselton', 'cidreira', 'grand centre', 'hilo', 'hofn', 'sinjai', 'grand river south east', 'talnakh', 'kodiak', 'olga', 'elban', 'kapaa', 'ossora', 'longyearbyen', 'albany', 'hambantota', 'cayenne', 'mabopane', 'adrasmon', 'mar del plata', 'tuatapere', 'kupang', 'roald', 'belushya guba', 'klaksvik', 'chuy', 'labuhan', 'puerto ayora', 'arraial do cabo', 'ahipara', 'bethel', 'sao filipe', 'kavieng', 'kahului', 'presidencia roque saenz pena', 'avarua', 'dingle', 'mahebourg', 'graaff-reinet', 'karratha', 'seminole', 'carballo', 'breyten', 'mys shmidta', 'katangli', 'port alfred', 'hermanus', 'mareeba', 'ilulissat', 'rio cuarto', 'souillac', 'new norfolk', 'sentyabrskiy', 'nikolskoye', 'ostrovnoy', 'juegang', 'noyabrsk', 'shache', 'marmaron', 'doha', 'cherskiy', 'evanston', 'chokurdakh', 'amderma', 'nouadhibou', 'nong han', 'kulhudhuffushi', 'atasu', 'newport', 'attawapiskat', 'cape town', 'jamestown', 'atuona', 'saskylakh', 'thompson', 'acapulco', 'port lincoln', 'waimana', 'cockburn town', 'guerrero negro', 'itupiranga', 'laguna', 'zeulenroda', 'barrow', 'yambio', 'sao gabriel da cachoeira', 'khatanga', 'palotina', 'vaini', 'port-de-paix', 'puerto carreno', 'umzimvubu', 'lorengau', 'chara', 'yumen', 'airai', 'castro', 'chagda', 'ponta delgada', 'beringovskiy', 'peleduy', 'uruguaiana', 'gat', 'nantucket', 'taolanaro', 'lata', 'garowe', 'fevralsk', 'san rafael', 'port hawkesbury', 'tasiilaq', 'changli', 'mamallapuram', 'san vicente', 'tarauaca', 'poroshkovo', 'viedma', 'butaritari', 'henties bay', 'pitimbu', 'mount gambier', 'usinsk', 'lompoc', 'sitka', 'lardos', 'talcahuano', 'georgetown', 'qaanaaq', 'malwan', 'saint george', 'leningradskiy', 'hobart', 'walvis bay', 'andenes', 'mabaruma', 'la ronge', 'veraval', 'bilibino', 'lagoa', 'iskateley', 'kruisfontein', 'tapaua', 'kuala terengganu', 'trat', 'illoqqortoormiut', 'torbay', 'flinders', 'kholmogory', 'waitati', 'toliary', 'toba', 'ucluelet', 'bambous virieux', 'kirakira', 'bira', 'jijiga', 'san patricio', 'grand gaube', 'correntina', 'east london', 'terme', 'sindor', 'codrington', 'mount darwin', 'hithadhoo', 'rendsburg', 'chapais', 'grindavik', 'faanui', 'asau', 'norman wells', 'rambha', 'padang', 'tiksi', 'guilin', 'bella vista', 'byron bay', 'caravelas', 'lavrentiya', 'biak', 'yara', 'vestmannaeyjar', 'juan lacaze', 'bur gabo', 'port augusta', 'jiangyou', 'pochutla', 'metehara', 'cabra', 'xai-xai', 'hare bay', 'martapura', 'tautira', 'nyurba', 'oistins', 'carnarvon', 'cururupu', 'bonavista', 'seoul', 'netanya', 'novorzhev', 'chiredzi', 'pangnirtung', 'bintulu', 'hvide sande', 'jining', 'cabo san lucas', 'bengkulu', 'contamana', 'noumea', 'deputatskiy', 'vila franca do campo', 'tutoia', 'zyryanka', 'vanimo', 'sergeyevka', 'roanoke', 'nassau', 'angra', 'hobyo', 'agua verde', 'kargasok', 'yar-sale', 'abiy adi', 'otukpo', 'longlac', 'waddan', 'devils lake', 'det udom', 'fortuna', 'poum', 'ponta do sol', 'kayes', 'barentsburg', 'mikhaylovka', 'monster', 'kaitangata', 'babu', 'naze', 'saint-philippe', 'kudahuvadhoo', 'ingham', 'ewa beach', 'gizo', 'margate', 'shahr-e babak', 'burnie', 'mirabad', 'hirara', 'chaozhou', 'nabire', 'husavik', 'bria', 'waterloo', 'marcona', 'jahrom', 'shenjiamen', 'rajpipla', 'vardo', 'zhanakorgan', 'asfi', 'provideniya', 'victoria', 'mackay', 'pisco', 'kilifarevo', 'inuvik', 'rio gallegos', 'iqaluit', 'savannah bight', 'kijang', 'ampanihy', 'fare', 'bubaque', 'fukue', 'namibe', 'jalu', 'kununurra', 'geraldton', 'lebu', 'kirov', 'los llanos de aridane', 'shestakovo', 'nuuk', 'aykhal', 'faya', 'upernavik', 'napanee', 'campbeltown', 'bandarbeyla', 'dvinskoy', 'dunedin', 'malakal', 'san policarpo', 'bowmore', 'katherine ...

# %%
api_key = weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

response = requests.get(query_url + cities[1]).json()

# %%
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 6},
#  'cod': 200,
#  'coord': {'lat': -33.92, 'lon': 25.57},
#  'dt': 1587405605,
#  'id': 964420,
#  'main': {'feels_like': 62.08,
#           'humidity': 77,
#           'pressure': 1018,
#           'temp': 64.4,
#           'temp_max': 64.4,
#           'temp_min': 64.4},
#  'name': 'Port Elizabeth',
#  'sys': {'country': 'ZA',
#          'id': 1973,
#          'sunrise': 1587357848,
#          'sunset': 1587397716,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 230, 'speed': 8.05}}

# %%
weather_dict = {
    "City" : cities,
    "Country" : None,
    "Latitude" : None,
    "Longitude" : None,
    "Temperature (F)" : None,
    "Humidity (%)" : None,
    "Cloudiness (%)" : None,
    "Wind Speed (MPH)" : None
}

weather_df = pd.DataFrame(weather_dict).set_index("City")

test_df = weather_df.head(30)
weather_df.head()
# Out:
#                Country Latitude Longitude Temperature (F) Humidity (%)  \
# City
# alotau            None     None      None            None         None
# port elizabeth    None     None      None            None         None
# nizhneyansk       None     None      None            None         None
# palana            None     None      None            None         None
# punta arenas      None     None      None            None         None
#
#                Cloudiness (%) Wind Speed (MPH)
# City
# alotau                   None             None
# port elizabeth           None             None
# nizhneyansk              None             None
# palana                   None             None
# punta arenas             None             None

# %%
x=1
for i, row in weather_df.iterrows():
    city = i

    try:
        # Make the request and print which place it's looking up
        response = requests.get(query_url + city).json()
        print(f"Gathering information for city number {x}, {i}")
        x+=1
        try:
            # If there was a result, add it to the df
            if response and len(response):
                weather_df.loc[i, "Country"] = response["sys"]["country"]
                weather_df.loc[i, "Latitude"] = response["coord"]["lat"]
                weather_df.loc[i, "Longitude"] = response["coord"]["lon"]
                weather_df.loc[i, "Temperature (F)"] = response["main"]["temp_max"]
                weather_df.loc[i, "Humidity (%)"] = response["main"]["humidity"]
                weather_df.loc[i, "Cloudiness (%)"] = response["clouds"]["all"]
                weather_df.loc[i, "Wind Speed (MPH)"] = response["wind"]["speed"]

        except KeyError:
            print("Missing values....skipping")


    except KeyError:
        print("index can't be found....skipping")
# Out:
#  metehara
# Missing values....skipping
# Gathering information for city number 214, cabra
# Gathering information for city number 215, xai-xai
# Gathering information for city number 216, hare bay
# Gathering information for city number 217, martapura
# Gathering information for city number 218, tautira
# Gathering information for city number 219, nyurba
# Gathering information for city number 220, oistins
# Gathering information for city number 221, carnarvon
# Gathering information for city number 222, cururupu
# Gathering information for city number 223, bonavista
# Gathering information for city number 224, seoul
# Gathering information for city number 225, netanya
# Gathering information for city number 226, novorzhev
# Gathering information for city number 227, chiredzi
# Gathering information for city number 228, pangnirtung
# Gathering information for city number 229, bintulu
# Gathering information for city number 230, hvide sande
# Gathering information for city number 231, jining
# Gathering information for city number 232, cabo san lucas
# Gathering information for city number 233, bengkulu
# Gathering information for city number 234, contamana
# Gathering information for city number 235, noumea
# Gathering information for city number 236, deputatskiy
# Gathering information for city number 237, vila franca do campo
# Gathering information for city number 238, tutoia
# Gathering information for city number 239, zyryanka
# Gathering information for city number 240, vanimo
# Gathering information for city number 241, sergeyevka
# Gathering information for city number 242, roanoke
# Gathering information for city number 243, nassau
# Gathering information for city number 244, angra
# Missing values....skipping
# Gathering information for city number 245, hobyo
# Gathering information for city number 246, agua verde
# Gathering information for city number 247, kargasok
# Gathering information for city number 248, yar-sale
# Gathering information for city number 249, abiy adi
# Missing values....skipping
# Gathering information for city number 250, otukpo
# Gathering information for city number 251, longlac
# Missing values....skipping
# Gathering information for city number 252, waddan
# Gathering information for city number 253, devils lake
# Gathering information for city number 254, det udom
# Gathering information for city number 255, fortuna
# Gathering information for city number 256, poum
# Gathering information for city number 257, ponta do sol
# Gathering information for city number 258, kayes
# Gathering information for city number 259, barentsburg
# Missing values....skipping
# Gathering information for city number 260, mikhaylovka
# Gathering information for city number 261, monster
# Gathering information for city number 262, kaitangata
# Gathering information for city number 263, babu
# Gathering information for city number 264, naze
# Gathering information for city number 265, saint-philippe
# Gathering information for city number 266, kudahuvadhoo
# Gathering information for city number 267, ingham
# Gathering information for city number 268, ewa beach
# Gathering information for city number 269, gizo
# Gathering information for city number 270, margate
# Gathering information for city number 271, shahr-e babak
# Gathering information for city number 272, burnie
# Gathering information for city number 273, mirabad
# Gathering information for city number 544, itoman
# Gathering information for city number 545, deep river
# Gathering information for city number 546, georgiyevskoye
# Gathering information for city number 547, shakiso
# Gathering information for city number 548, san andres
# Gathering information for city number 549, port jervis
# Gathering information for city number 550, hay river
# Gathering information for city number 551, ouricuri
# Gathering information for city number 552, ust-ilimsk
# Gathering information for city number 553, edgewater
# Gathering information for city number 554, taunton
# Gathering information for city number 555, salalah
# Gathering information for city number 556, suez
# Gathering information for city number 557, bowen
# Gathering information for city number 558, rawson
# Gathering information for city number 559, macenta
# Gathering information for city number 560, cairo
# Gathering information for city number 561, samarai
# Gathering information for city number 562, kodinsk
# Gathering information for city number 563, harper
# Gathering information for city number 564, lamu
# Gathering information for city number 565, derzhavinsk
# Gathering information for city number 566, terpinnya
# Gathering information for city number 567, maniitsoq
# Gathering information for city number 568, bodmin
# Gathering information for city number 569, sao felix do xingu
# Gathering information for city number 570, druzhba
# Gathering information for city number 571, medvezhyegorsk
# Gathering information for city number 572, mataram
# Gathering information for city number 573, vao
# Gathering information for city number 574, skibbereen
# Gathering information for city number 575, saldanha
# Gathering information for city number 576, tamandare
# Gathering information for city number 577, tidore
# Missing values....skipping
# Gathering information for city number 578, sawtell
# Gathering information for city number 579, celestun
# Gathering information for city number 580, calvia
# Gathering information for city number 581, taburao
# Missing values....skipping
# Gathering information for city number 582, kamenka
# Gathering information for city number 583, pergine valsugana
# Gathering information for city number 584, gazanjyk
# Gathering information for city number 585, leshukonskoye

# %%
weather_df.head()
# Out:
#                Country Latitude Longitude Temperature (F) Humidity (%)  \
# City
# alotau            None     None      None            None         None
# port elizabeth      ZA   -33.92     25.57            64.4           77
# nizhneyansk       None     None      None            None         None
# palana              RU    59.12    159.97            5.92           93
# punta arenas        CL   -53.15    -70.92            51.8           62
#
#                Cloudiness (%) Wind Speed (MPH)
# City
# alotau                   None             None
# port elizabeth              6             8.05
# nizhneyansk              None             None
# palana                     99             2.26
# punta arenas               75            29.97

# %%
weather_df = weather_df.dropna()

# %% [markdown]
# ## Make Scatter Plots for the following:
#
# - Temperature (F) vs. Latitude
# - Humidity (%) vs. Latitude
# - Cloudiness (%) vs. Latitude
# - Wind Speed (mph) vs. Latitude

# %%
# Create a function to make scatter plots
# Variables are : dataframe name, x_axis column name, y_axis column name, hemisphere, filename
def plot(df, x, y, hem, name):
    plt.scatter(df[x], df[y])
    plt.xlabel(x)
    plt.ylabel(y)
    plt.title(f"{hem} {x} v {y}")
    plt.savefig(f"output_data/{name}.png")
    plt.show()

# %%
plot(weather_df, "Latitude", "Temperature (F)", "World", "latTemp")

# %%
plot(weather_df, "Latitude", "Humidity (%)", "World", "latHum")

# %%
plot(weather_df, "Latitude", "Cloudiness (%)", "World", "latCloud")

# %%
plot(weather_df, "Latitude", "Wind Speed (MPH)", "World", "latWind")

# %% [markdown]
# ## Northern and Southern Hemispheres
# ## Make Scatter Plots with Linear Regressions for the following:
# - Northern Hemisphere - Temperature (F) vs. Latitude
# - Southern Hemisphere - Temperature (F) vs. Latitude
# - Northern Hemisphere - Humidity (%) vs. Latitude
# - Southern Hemisphere - Humidity (%) vs. Latitude
# - Northern Hemisphere - Cloudiness (%) vs. Latitude
# - Southern Hemisphere - Cloudiness (%) vs. Latitude
# - Northern Hemisphere - Wind Speed (mph) vs. Latitude
# - Southern Hemisphere - Wind Speed (mph) vs. Latitude

# %%
# Separate out the data
north_df = weather_df[weather_df["Latitude"] > 0]
south_df = weather_df[weather_df["Latitude"] < 0]

# %%
# Make a function for linear regressions
# The variables are: Dataframe, x_axis column name, y_axis column name, where the equation should show up
def linreg(df, x, y, a, b):

    # Need to convert to numeric for calculations
    x_axis = pd.to_numeric(df[x])
    y_axis = pd.to_numeric(df[y])

    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    predictions = x_axis * slope + intercept
    line_eq = f'y = {round(intercept,2)} + {round(slope,2)}x'
    plt.plot(x_axis ,predictions,"r-")
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")
    print(f"The correlation between {x} and {y} is {round(rvalue,2)}")

# %%
# Name x and y to save keystrokes
x= "Latitude"
y= "Temperature (F)"
print("NORTHERN HEMISPHERE")

# Call the functions
linreg(north_df, x, y, 5, 0)
plot(north_df, x, y, "Northern", "northLatTemp")
# Out:
# NORTHERN HEMISPHERE
# The correlation between Latitude and Temperature (F) is -0.87

# %%
x= "Latitude"
y= "Temperature (F)"
print("SOUTHERN HEMISPHERE")
linreg(south_df, x, y, -25, 50)
plot(south_df, x, y, "Southern", "southLatTemp")
# Out:
# SOUTHERN HEMISPHERE
# The correlation between Latitude and Temperature (F) is 0.74

# %%
x= "Latitude"
y= "Humidity (%)"
print("NORTHERN HEMISPHERE")
linreg(north_df, x, y, 47, 15)
plot(north_df, x, y, "Northern", "northLatHum")
# Out:
# NORTHERN HEMISPHERE
# The correlation between Latitude and Humidity (%) is 0.24

# %%
x= "Latitude"
y= "Humidity (%)"
print("SOUTHERN HEMISPHERE")
linreg(south_df, x, y, -50, 110)
# Make room for the equation
plt.ylim(-3,120)
plot(south_df, x, y, "Southern", "southLatHum")
# Out:
# SOUTHERN HEMISPHERE
# The correlation between Latitude and Humidity (%) is 0.13

# %%
x= "Latitude"
y= "Cloudiness (%)"
print("NORTHERN HEMISPHERE")
linreg(north_df, x, y, 0, 110)
# Make room for the equation
plt.ylim(-3,120)
plot(north_df, x, y, "Northern", "northLatCloud")
# Out:
# NORTHERN HEMISPHERE
# The correlation between Latitude and Cloudiness (%) is 0.15

# %%
x= "Latitude"
y= "Cloudiness (%)"
print("SOUTHERN HEMISPHERE")
linreg(south_df, x, y, -50, 110)
# Make room for the equation
plt.ylim(-3,120)
plot(south_df, x, y, "Southern", "southLatCloud")
# Out:
# SOUTHERN HEMISPHERE
# The correlation between Latitude and Cloudiness (%) is 0.07

# %%
x= "Latitude"
y= "Wind Speed (MPH)"
print("NORTHERN HEMISPHERE")
linreg(north_df, x, y, 0, 32)
plot(north_df, x, y, "Northern", "northLatWind")
# Out:
# NORTHERN HEMISPHERE
# The correlation between Latitude and Wind Speed (MPH) is 0.08

# %%
x= "Latitude"
y= "Wind Speed (MPH)"
print("SOUTHERN HEMISPHERE")
linreg(south_df, x, y, -30, 30)
plot(south_df, x, y, "Southern", "southLatWind")
# Out:
# SOUTHERN HEMISPHERE
# The correlation between Latitude and Wind Speed (MPH) is -0.19

# %%
# Output the df as a file

weather_df.to_csv(output_data, index=True, header=True)
